# %%
import pandas as pd
import random
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import f1_score, roc_auc_score, average_precision_score, confusion_matrix
import matplotlib.pyplot as plt
from sklearn.model_selection import StratifiedKFold
from sklearn.ensemble import RandomForestRegressor
from scipy import stats
import numpy as np

# %% [markdown]
# # Read data

# %%
norm = 'True' # or False

# %%
wcct = pd.read_csv('WCCT_data.csv')
wcct.head()
# Out:
#    VOLUNTEER         DAY  B.cells.plasma.STAT5+  Basophils    Bcells  \
# 0        101  Baseline 1               0.003108   1.712350  5.394990
# 1        101  Baseline 2               0.000000   1.545919  6.057033
# 2        101           1               0.000000   1.537663  5.168144
# 3        101           2               0.003162   1.479935  4.920469
# 4        101           3               0.000000   1.613706  6.140787
#
#    Bcells.CSM  Bcells.NCSM  Bcells.plasma      CD66+       cMCs  ...  \
# 0    1.103238     0.643297       0.046616  58.753327  25.943191  ...
# 1    1.218394     0.768593       0.026202  54.366529  24.429014  ...
# 2    1.034428     0.571132       0.027958  66.719099  29.427271  ...
# 3    0.961326     0.645100       0.044272  66.973242  26.581918  ...
# 4    1.069585     0.609415       0.043530  64.295463  27.734594  ...
#
#    Tcells.CD8+.CD161+  Tcells.CD8+.CD38+  Tcells.CD8+.CD38+Ki67+  \
# 0            0.829759           0.180247                0.105662
# 1            0.790428           0.231451                0.152845
# 2            0.635035           0.195703                0.131800
# 3            0.562881           0.252980                0.123328
# 4            0.513028           0.195883                0.071513
#
#    Tcells.CD8+.Effector.CD38+  Tcells.CD8+.Effector.CD38+Ki67+  \
# 0                    0.015539                         0.006215
# 1                    0.017468                         0.008734
# 2                    0.000000                         0.000000
# 3                    0.006325                         0.003162
# 4                    0.006219                         0.003109
#
#    Tcells.CD8+.Memory  Tcells.CD8+.Memory.CD38+  \
# 0            4.583877                  0.087016
# 1            4.908511                  0.061138
# 2            3.993929                  0.095854
# 3            4.003415                  0.091705
# 4            3.867919                  0.090169
#
#    Tcells.CD8+.Memory.CD38+Ki67+  Tcells.CD8+CD45RA+CD27-  label
# 0                       0.065262                 1.945429      1
# 1                       0.056771                 1.248963      1
# 2                       0.063903                 1.282051      1
# 3                       0.050596                 1.862568      1
# 4                       0.049748                 1.402276      1
#
# [5 rows x 46 columns]

# %%
vxa = pd.read_csv('VXA_data.csv')
vxa.head()
# Out:
#    VOLUNTEER         DAY  B Cells Plasma STAT5+  Basophils   B Cells  \
# 0        107  Baseline 1               0.004185   2.657627  8.008454
# 1        107  Baseline 2               0.030483   1.879795  6.987417
# 2        107           1               0.014398   1.906895  6.810110
# 3        107           2               0.010650   1.830298  5.430036
# 4        107           3               0.002682   2.012604  4.848485
#
#    B Cells CSM  B Cells NCSM  B Cells Plasma       CD66+       cMCs  ...  \
# 0     1.017013      1.332999        0.012556  145.606546  13.706657  ...
# 1     0.990703      1.251503        0.049112  160.244881  13.653068  ...
# 2     1.047832      1.035034        0.025596  165.547912  15.797472  ...
# 3     0.769851      0.874831        0.022822  196.138573  20.163707  ...
# 4     0.662376      0.691874        0.010727  177.886833  23.716814  ...
#
#    CD8 T Cells CD161+  CD8 T Cells CD38+  CD8 T Cells CD38+Ki67+  \
# 0            4.436353           0.039760                0.033482
# 1            3.381937           0.064353                0.123626
# 2            3.781795           0.035194                0.075188
# 3            3.167648           0.022822                0.065422
# 4            3.259587           0.049611                0.073746
#
#    CD8 T Cells CD45RA+CD27- CD38+  CD8 T Cells CD45RA+CD27- CD38+Ki67+  \
# 0                        0.002093                             0.004185
# 1                        0.001694                             0.001694
# 2                        0.001600                             0.003199
# 3                        0.000000                             0.003043
# 4                        0.000000                             0.008045
#
#    CD8 T Cells Memory  CD8 T Cells Memory CD38+  \
# 0           22.799088                  0.108816
# 1           21.634575                  0.193060
# 2           19.644857                  0.135978
# 3           18.321238                  0.135409
# 4           17.035398                  0.164924
#
#    CD8 T Cells Memory CD38+Ki67+  CD8 T Cells CD45RA+CD27-  label
# 0                       0.140205                  1.697114      1
# 1                       0.204915                  2.003421      1
# 2                       0.148776                  2.583587      1
# 3                       0.144537                  2.697522      1
# 4                       0.151515                  2.240547      1
#
# [5 rows x 46 columns]

# %% [markdown]
# # Preprocess data

# %%
def reverse_days(x):
    if x == 'Baseline 1':
        return -1
    if x == 'Baseline 2':
        return 1
    else:
        return int(x) +1

# %%
wcct['DAY'] = wcct['DAY'].apply(lambda x: reverse_days(x))
vxa['DAY'] = vxa['DAY'].apply(lambda x: reverse_days(x))

# %%
wcct.head()
# Out:
#    VOLUNTEER  DAY  B.cells.plasma.STAT5+  Basophils    Bcells  Bcells.CSM  \
# 0        101   -1               0.003108   1.712350  5.394990    1.103238
# 1        101    1               0.000000   1.545919  6.057033    1.218394
# 2        101    2               0.000000   1.537663  5.168144    1.034428
# 3        101    3               0.003162   1.479935  4.920469    0.961326
# 4        101    4               0.000000   1.613706  6.140787    1.069585
#
#    Bcells.NCSM  Bcells.plasma      CD66+       cMCs  ...  Tcells.CD8+.CD161+  \
# 0     0.643297       0.046616  58.753327  25.943191  ...            0.829759
# 1     0.768593       0.026202  54.366529  24.429014  ...            0.790428
# 2     0.571132       0.027958  66.719099  29.427271  ...            0.635035
# 3     0.645100       0.044272  66.973242  26.581918  ...            0.562881
# 4     0.609415       0.043530  64.295463  27.734594  ...            0.513028
#
#    Tcells.CD8+.CD38+  Tcells.CD8+.CD38+Ki67+  Tcells.CD8+.Effector.CD38+  \
# 0           0.180247                0.105662                    0.015539
# 1           0.231451                0.152845                    0.017468
# 2           0.195703                0.131800                    0.000000
# 3           0.252980                0.123328                    0.006325
# 4           0.195883                0.071513                    0.006219
#
#    Tcells.CD8+.Effector.CD38+Ki67+  Tcells.CD8+.Memory  \
# 0                         0.006215            4.583877
# 1                         0.008734            4.908511
# 2                         0.000000            3.993929
# 3                         0.003162            4.003415
# 4                         0.003109            3.867919
#
#    Tcells.CD8+.Memory.CD38+  Tcells.CD8+.Memory.CD38+Ki67+  \
# 0                  0.087016                       0.065262
# 1                  0.061138                       0.056771
# 2                  0.095854                       0.063903
# 3                  0.091705                       0.050596
# 4                  0.090169                       0.049748
#
#    Tcells.CD8+CD45RA+CD27-  label
# 0                 1.945429      1
# 1                 1.248963      1
# 2                 1.282051      1
# 3                 1.862568      1
# 4                 1.402276      1
#
# [5 rows x 46 columns]

# %%
vxa.head()
# Out:
#    VOLUNTEER  DAY  B Cells Plasma STAT5+  Basophils   B Cells  B Cells CSM  \
# 0        107   -1               0.004185   2.657627  8.008454     1.017013
# 1        107    1               0.030483   1.879795  6.987417     0.990703
# 2        107    2               0.014398   1.906895  6.810110     1.047832
# 3        107    3               0.010650   1.830298  5.430036     0.769851
# 4        107    4               0.002682   2.012604  4.848485     0.662376
#
#    B Cells NCSM  B Cells Plasma       CD66+       cMCs  ...  \
# 0      1.332999        0.012556  145.606546  13.706657  ...
# 1      1.251503        0.049112  160.244881  13.653068  ...
# 2      1.035034        0.025596  165.547912  15.797472  ...
# 3      0.874831        0.022822  196.138573  20.163707  ...
# 4      0.691874        0.010727  177.886833  23.716814  ...
#
#    CD8 T Cells CD161+  CD8 T Cells CD38+  CD8 T Cells CD38+Ki67+  \
# 0            4.436353           0.039760                0.033482
# 1            3.381937           0.064353                0.123626
# 2            3.781795           0.035194                0.075188
# 3            3.167648           0.022822                0.065422
# 4            3.259587           0.049611                0.073746
#
#    CD8 T Cells CD45RA+CD27- CD38+  CD8 T Cells CD45RA+CD27- CD38+Ki67+  \
# 0                        0.002093                             0.004185
# 1                        0.001694                             0.001694
# 2                        0.001600                             0.003199
# 3                        0.000000                             0.003043
# 4                        0.000000                             0.008045
#
#    CD8 T Cells Memory  CD8 T Cells Memory CD38+  \
# 0           22.799088                  0.108816
# 1           21.634575                  0.193060
# 2           19.644857                  0.135978
# 3           18.321238                  0.135409
# 4           17.035398                  0.164924
#
#    CD8 T Cells Memory CD38+Ki67+  CD8 T Cells CD45RA+CD27-  label
# 0                       0.140205                  1.697114      1
# 1                       0.204915                  2.003421      1
# 2                       0.148776                  2.583587      1
# 3                       0.144537                  2.697522      1
# 4                       0.151515                  2.240547      1
#
# [5 rows x 46 columns]

# %%
if norm == 'True':
    wcct.loc[:,  (wcct.columns != 'VOLUNTEER') &  (wcct.columns != 'DAY') & (wcct.columns != 'label')] = \
        wcct.loc[:,  (wcct.columns != 'VOLUNTEER') &  (wcct.columns != 'DAY') & (wcct.columns != 'label')].subtract(
        (wcct.groupby('VOLUNTEER').transform(lambda x:x.iloc[0])))#.round(2)

# %%
if norm == 'True':
    vxa.loc[:,  (vxa.columns != 'VOLUNTEER') &  (vxa.columns != 'DAY') & (vxa.columns != 'label')] = \
        vxa.loc[:,  (vxa.columns != 'VOLUNTEER') &  (vxa.columns != 'DAY') & (vxa.columns != 'label')].subtract(
        (vxa.groupby('VOLUNTEER').transform(lambda x:x.iloc[0])))#.round(2)

# %% [markdown]
# # Match cell populations

# %%
# use common populations
mcl = pd.read_excel('matched_populations.xlsx')
wcct_cols = mcl['WCCT'].values.tolist()
wcct_cols.extend(['VOLUNTEER', 'DAY', 'label'])
vxa_cols = mcl['VXA'].values.tolist()
vxa_cols.extend(['VOLUNTEER', 'DAY', 'label'])
mcl.head()
# Out:
#    index                    VXA                   WCCT
# 0      1  B Cells Plasma STAT5+  B.cells.plasma.STAT5+
# 1      2              Basophils              Basophils
# 2      3                B Cells                 Bcells
# 3      4            B Cells CSM             Bcells.CSM
# 4      5           B Cells NCSM            Bcells.NCSM

# %%
wcct = wcct[wcct_cols]
vxa = vxa[vxa_cols]

# %%
wcct.head()
# Out:
#    B.cells.plasma.STAT5+  Basophils    Bcells  Bcells.CSM  Bcells.NCSM  \
# 0               0.000000   0.000000  0.000000    0.000000     0.000000
# 1              -0.003108  -0.166431  0.662043    0.115156     0.125296
# 2              -0.003108  -0.174687 -0.226846   -0.068811    -0.072165
# 3               0.000055  -0.232415 -0.474521   -0.141913     0.001803
# 4              -0.003108  -0.098644  0.745797   -0.033653    -0.033882
#
#    Bcells.plasma     CD66+      cMCs    intMCs       mDC  ...  \
# 0       0.000000  0.000000  0.000000  0.000000  0.000000  ...
# 1      -0.020414 -4.386798 -1.514177 -0.642958  0.123234  ...
# 2      -0.018658  7.965772  3.484080 -0.741623  0.519418  ...
# 3      -0.002344  8.219915  0.638727 -0.879535  1.077903  ...
# 4      -0.003086  5.542136  1.791403 -0.838885  0.572898  ...
#
#    Tcells.CD8+.CD38+Ki67+  Tcells.CD8+.Effector.CD38+  \
# 0                0.000000                    0.000000
# 1                0.047183                    0.001929
# 2                0.026137                   -0.015539
# 3                0.017666                   -0.009214
# 4               -0.034149                   -0.009320
#
#    Tcells.CD8+.Effector.CD38+Ki67+  Tcells.CD8+.Memory  \
# 0                         0.000000            0.000000
# 1                         0.002519            0.324634
# 2                        -0.006215           -0.589948
# 3                        -0.003053           -0.580462
# 4                        -0.003106           -0.715959
#
#    Tcells.CD8+.Memory.CD38+  Tcells.CD8+.Memory.CD38+Ki67+  \
# 0                  0.000000                       0.000000
# 1                 -0.025878                      -0.008491
# 2                  0.008838                      -0.001359
# 3                  0.004689                      -0.014666
# 4                  0.003153                      -0.015514
#
#    Tcells.CD8+CD45RA+CD27-  VOLUNTEER  DAY  label
# 0                 0.000000        101   -1      1
# 1                -0.696466        101    1      1
# 2                -0.663377        101    2      1
# 3                -0.082860        101    3      1
# 4                -0.543153        101    4      1
#
# [5 rows x 46 columns]

# %%
vxa.head()
# Out:
#    B Cells Plasma STAT5+  Basophils   B Cells  B Cells CSM  B Cells NCSM  \
# 0               0.000000   0.000000  0.000000     0.000000      0.000000
# 1               0.026298  -0.777832 -1.021037    -0.026310     -0.081496
# 2               0.010212  -0.750732 -1.198344     0.030819     -0.297964
# 3               0.006465  -0.827328 -2.578418    -0.247162     -0.458168
# 4              -0.001504  -0.645023 -3.159969    -0.354637     -0.641124
#
#    B Cells Plasma      CD66+       cMCs    intMCs      mDCs  ...  \
# 0        0.000000   0.000000   0.000000  0.000000  0.000000  ...
# 1        0.036556  14.638336  -0.053589 -0.223652  0.053221  ...
# 2        0.013040  19.941367   2.090816  0.109187  0.165704  ...
# 3        0.010266  50.532027   6.457051  0.978653  0.155394  ...
# 4       -0.001829  32.280287  10.010158  3.759264 -0.067880  ...
#
#    CD8 T Cells CD38+Ki67+  CD8 T Cells CD45RA+CD27- CD38+  \
# 0                0.000000                        0.000000
# 1                0.090144                       -0.000399
# 2                0.041706                       -0.000493
# 3                0.031940                       -0.002093
# 4                0.040264                       -0.002093
#
#    CD8 T Cells CD45RA+CD27- CD38+Ki67+  CD8 T Cells Memory  \
# 0                             0.000000            0.000000
# 1                            -0.002492           -1.164513
# 2                            -0.000986           -3.154231
# 3                            -0.001142           -4.477850
# 4                             0.003860           -5.763689
#
#    CD8 T Cells Memory CD38+  CD8 T Cells Memory CD38+Ki67+  \
# 0                  0.000000                       0.000000
# 1                  0.084244                       0.064709
# 2                  0.027162                       0.008571
# 3                  0.026592                       0.004332
# 4                  0.056107                       0.011310
#
#    CD8 T Cells CD45RA+CD27-  VOLUNTEER  DAY  label
# 0                  0.000000        107   -1      1
# 1                  0.306307        107    1      1
# 2                  0.886472        107    2      1
# 3                  1.000407        107    3      1
# 4                  0.543433        107    4      1
#
# [5 rows x 46 columns]

# %%
# filter unwanted days out
tr_days = [2,3,4,5,6,7,8]
wcct = wcct[(wcct['DAY'].isin(tr_days)) ]
vxa = vxa[(vxa['DAY'].isin(tr_days))]

# %%
def evaluate_preds(true, pred):
    auc = roc_auc_score(true, pred)
    pr = average_precision_score(true, pred)
    bin_pred = [1 if p > 0.5 else 0 for p in pred]
    f_score = f1_score(true, bin_pred)
    return auc, pr, f_score

# %% [markdown]
# ## Random Forest

# %% [markdown]
# # Classification

# %%
from sklearn.metrics import roc_auc_score
tr_days = [2,3,4,5,6,7,8]
tr_x = wcct[wcct['DAY'].isin(tr_days)].drop(['VOLUNTEER', 'DAY', 'label'], axis =1)
tr_y = wcct[wcct['DAY'].isin(tr_days)]['label']
for d in [2,3,4,6]:
    testx = vxa[vxa['DAY']==d].drop(['VOLUNTEER', 'DAY', 'label'], axis =1)
    testy =  vxa[vxa['DAY']==d]['label']
    aucs = []
    for i in range(10): # change 10 for bootstrapping
        RF = RandomForestClassifier(random_state = random.seed(1234))
        RF.fit(tr_x, tr_y)
        probs = RF.predict_proba(testx)  
        probs = probs[:, 1]  
        auc_ = roc_auc_score(testy, probs)
        aucs.append(auc_)
    #print('day %s'%d, np.mean(aucs))

# %% [markdown]
# # Filter shedders

# %%
wcct = wcct[(wcct['label']==1) & (~wcct['VOLUNTEER'].isin([101,109,304]))]
vxa = vxa[vxa['label']==1]

# %%
wcct.head()
# Out:
#     B.cells.plasma.STAT5+  Basophils    Bcells  Bcells.CSM  Bcells.NCSM  \
# 24              -0.051331  -0.320943 -0.561717   -0.027045     0.021157
# 25              -0.030780  -0.167358 -0.127951   -0.058401     0.060127
# 26              -0.040322  -0.364959 -0.414351   -0.135249     0.002995
# 27              -0.097732  -0.587658 -1.068621   -0.172138    -0.118536
# 28              -0.078188  -0.645096 -0.641137   -0.104277    -0.108517
#
#     Bcells.plasma     CD66+      cMCs    intMCs       mDC  ...  \
# 24       0.007392 -2.245394  4.438926 -0.117166  0.202109  ...
# 25       0.005042 -1.324993  3.512354 -0.280401  0.520787  ...
# 26      -0.056090  0.124590  8.065160  0.290708  0.171458  ...
# 27      -0.035305 -2.189082  7.526682  1.344945  0.127305  ...
# 28       0.038055 -4.108122  6.297360  1.533281 -0.019842  ...
#
#     Tcells.CD8+.CD38+Ki67+  Tcells.CD8+.Effector.CD38+  \
# 24                0.025071                    0.012010
# 25                0.012971                    0.008112
# 26                0.109093                    0.007139
# 27                0.152269                    0.029945
# 28                0.129443                    0.040351
#
#     Tcells.CD8+.Effector.CD38+Ki67+  Tcells.CD8+.Memory  \
# 24                         0.008966            0.000374
# 25                         0.005324           -0.080260
# 26                         0.004107            0.037023
# 27                         0.003421            0.171135
# 28                         0.012268            0.107582
#
#     Tcells.CD8+.Memory.CD38+  Tcells.CD8+.Memory.CD38+Ki67+  \
# 24                  0.067021                       0.042542
# 25                  0.085435                       0.006378
# 26                  0.140660                       0.051878
# 27                  0.280960                       0.093119
# 28                  0.284179                       0.048696
#
#     Tcells.CD8+CD45RA+CD27-  VOLUNTEER  DAY  label
# 24                -0.440921        103    2      1
# 25                -0.213460        103    3      1
# 26                -0.292690        103    4      1
# 27                 0.662680        103    5      1
# 28                 0.304579        103    6      1
#
# [5 rows x 46 columns]

# %%
vxa.head()
# Out:
#    B Cells Plasma STAT5+  Basophils   B Cells  B Cells CSM  B Cells NCSM  \
# 2               0.010212  -0.750732 -1.198344     0.030819     -0.297964
# 3               0.006465  -0.827328 -2.578418    -0.247162     -0.458168
# 4              -0.001504  -0.645023 -3.159969    -0.354637     -0.641124
# 5              -0.000616  -1.094253 -2.906668    -0.482801     -0.603662
# 6               0.088270  -1.527874 -2.587447    -0.169135     -0.261876
#
#    B Cells Plasma      CD66+       cMCs    intMCs      mDCs  ...  \
# 2        0.013040  19.941367   2.090816  0.109187  0.165704  ...
# 3        0.010266  50.532027   6.457051  0.978653  0.155394  ...
# 4       -0.001829  32.280287  10.010158  3.759264 -0.067880  ...
# 5       -0.000658 -41.516075   6.016362  6.384209 -0.011801  ...
# 6        0.111469 -75.566407   0.849335  0.792735  0.310580  ...
#
#    CD8 T Cells CD38+Ki67+  CD8 T Cells CD45RA+CD27- CD38+  \
# 2                0.041706                       -0.000493
# 3                0.031940                       -0.002093
# 4                0.040264                       -0.002093
# 5                0.098584                        0.006236
# 6                1.301475                        0.013692
#
#    CD8 T Cells CD45RA+CD27- CD38+Ki67+  CD8 T Cells Memory  \
# 2                            -0.000986           -3.154231
# 3                            -0.001142           -4.477850
# 4                             0.003860           -5.763689
# 5                             0.013661           -2.032630
# 6                             0.034150            1.996835
#
#    CD8 T Cells Memory CD38+  CD8 T Cells Memory CD38+Ki67+  \
# 2                  0.027162                       0.008571
# 3                  0.026592                       0.004332
# 4                  0.056107                       0.011310
# 5                  0.126761                       0.117977
# 6                  1.086331                       1.715655
#
#    CD8 T Cells CD45RA+CD27-  VOLUNTEER  DAY  label
# 2                  0.886472        107    2      1
# 3                  1.000407        107    3      1
# 4                  0.543433        107    4      1
# 5                  0.319566        107    6      1
# 6                  0.772105        107    8      1
#
# [5 rows x 46 columns]

# %% [markdown]
# # Regression

# %%
from scipy import stats

regr = RandomForestRegressor(random_state = random.seed())
trus = []
preds = []
to_write = pd.DataFrame()
X_tr = wcct.drop(['VOLUNTEER','DAY', 'label'], axis =1)
Y_tr = wcct['DAY']
clf = regr.fit(X_tr, Y_tr)
vxa_ids = list(set(vxa['VOLUNTEER'].values.tolist()))
vxa_days = list(set(vxa['DAY'].values.tolist()))
for n,id_ in enumerate(vxa_ids):
    for d in vxa_days:
        test = vxa[(vxa['VOLUNTEER']==id_) & (vxa['DAY']==d)]#.sample(n=1)
        X_te = test.drop(['VOLUNTEER','DAY', 'label'], axis =1)
        Y_te = test['DAY']
        if len(X_te)==0:
            continue
        pr = regr.predict(X_te)
        trus.extend(Y_te.values)
        preds.extend(pr)
        dic_ = {}
        dic_['iteration'] = d
        dic_['ID'] = id_
        dic_['true'] = Y_te.values
        dic_['predicted'] = pr
        to_write = to_write.append(dic_, ignore_index=True)

# %%
correlation, p_value = stats.pearsonr(trus,preds)
